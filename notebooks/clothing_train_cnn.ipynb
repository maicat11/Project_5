# %% [markdown]
# ## Clothing Classification Training

# %%
# %load_ext autoreload
# %reload_ext autoreload

import numpy as np
from glob import glob
import pickle

# import necessary keras modules
from keras.preprocessing import image 
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping  
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization

# custom functions
from layer_output import get_dense_layers, path_to_tensor, paths_to_tensor
from loading import load_files       

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path, ignore_files='.DS_Store')
    clothing_files = np.array(data['filenames'])
    clothing_targets = np_utils.to_categorical(np.array(data['target']), 14)
    return clothing_files, clothing_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('../data/clothing2/train')
valid_files, valid_targets = load_dataset('../data/clothing2/validate')
test_files, test_targets = load_dataset('../data/clothing2/test')

# load list of clothing names
clothing_names = [item[24:-1] for item in sorted(glob("../data/clothing2/train/*/"))]

# print info about the dataset
print(f'There are {len(clothing_names)} total clothing categories.')
print(f'There are {len(np.hstack([train_files, valid_files, test_files]))} total clothing images.\n')
print(f'There are {len(train_files)} training clothing images.')
print(f'There are {len(valid_files)} validation clothing images.')
print(f'There are {len(test_files)} test clothing images.')
# Out:
# There are 14 total clothing categories.
# There are 3147 total clothing images.
#
# There are 2477 training clothing images.
# There are 339 validation clothing images.
# There are 331 test clothing images.

# %% [markdown]
# **Convert all paths to a stack of tensors**

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
# rescale the images by dividing every pixel in every image by 255.
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 2477/2477 [00:21<00:00, 114.09it/s]
# 100%|██████████| 339/339 [00:02<00:00, 129.50it/s]
# 100%|██████████| 331/331 [00:02<00:00, 114.32it/s]

# %%
model = Sequential()

# Define the architecture.
model.add(BatchNormalization(input_shape=(224, 224, 3)))
model.add(Conv2D(filters=16, kernel_size=5, strides=2, padding='valid', activation='relu', 
                 input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=5, strides=2, padding='valid', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(rate=0.3))
model.add(Conv2D(filters=64, kernel_size=2, strides=2, padding='valid', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(GlobalAveragePooling2D())

model.add(Dense(units=300, activation='relu', name='vectors')) # extract vectors from here and cluster
model.add(Dropout(rate=0.3))
model.add(Dense(len(clothing_names), activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 224, 224, 3)       12
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 110, 110, 16)      1216
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 55, 55, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 32)        12832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# vectors (Dense)              (None, 300)               19500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 14)                4214
# =================================================================
# Total params: 46,030
# Trainable params: 46,024
# Non-trainable params: 6
# _________________________________________________________________

# %%
# compile the model 
# model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

datagen_train.fit(train_tensors)

# %%
epochs = 50

early_stop = EarlyStopping(monitor='val_loss', patience=5)

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)
history = model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=10, callbacks=[checkpointer, early_stop], verbose=1,)
# Out:
# Train on 2477 samples, validate on 339 samples
# Epoch 1/50
# 2477/2477 [==============================] - 18s 7ms/step - loss: 2.2393 - acc: 0.2358 - val_loss: 1.7965 - val_acc: 0.4100
#
# Epoch 00001: val_loss improved from inf to 1.79654, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 2/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 1.8109 - acc: 0.3932 - val_loss: 1.5955 - val_acc: 0.4277
#
# Epoch 00002: val_loss improved from 1.79654 to 1.59553, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 3/50
# 2477/2477 [==============================] - 16s 6ms/step - loss: 1.5539 - acc: 0.4885 - val_loss: 1.3611 - val_acc: 0.5339
#
# Epoch 00003: val_loss improved from 1.59553 to 1.36106, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 4/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 1.4172 - acc: 0.5301 - val_loss: 1.2734 - val_acc: 0.5988
#
# Epoch 00004: val_loss improved from 1.36106 to 1.27336, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 5/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 1.3377 - acc: 0.5700 - val_loss: 1.1127 - val_acc: 0.6283
#
# Epoch 00005: val_loss improved from 1.27336 to 1.11268, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 6/50
# 2477/2477 [==============================] - 17s 7ms/step - loss: 1.2414 - acc: 0.5894 - val_loss: 1.0577 - val_acc: 0.6696
#
# Epoch 00006: val_loss improved from 1.11268 to 1.05773, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 7/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 1.1950 - acc: 0.6169 - val_loss: 1.1107 - val_acc: 0.6490
#
# Epoch 00007: val_loss did not improve from 1.05773
# Epoch 8/50
# 2477/2477 [==============================] - 17s 7ms/step - loss: 1.1079 - acc: 0.6520 - val_loss: 1.0211 - val_acc: 0.6490
#
# Epoch 00008: val_loss improved from 1.05773 to 1.02114, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 9/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 1.0692 - acc: 0.6560 - val_loss: 1.0159 - val_acc: 0.6755
#
# Epoch 00009: val_loss improved from 1.02114 to 1.01591, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 10/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 1.0091 - acc: 0.6790 - val_loss: 0.9333 - val_acc: 0.7109
#
# Epoch 00010: val_loss improved from 1.01591 to 0.93328, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 11/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 0.9657 - acc: 0.6754 - val_loss: 0.7850 - val_acc: 0.7552
#
# Epoch 00011: val_loss improved from 0.93328 to 0.78500, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 12/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 0.9568 - acc: 0.6883 - val_loss: 0.8407 - val_acc: 0.7316
#
# Epoch 00012: val_loss did not improve from 0.78500
# Epoch 13/50
# 2477/2477 [==============================] - 17s 7ms/step - loss: 0.8783 - acc: 0.7142 - val_loss: 0.8522 - val_acc: 0.7257
#
# Epoch 00013: val_loss did not improve from 0.78500
# Epoch 14/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 0.8705 - acc: 0.7186 - val_loss: 0.7650 - val_acc: 0.7611
#
# Epoch 00014: val_loss improved from 0.78500 to 0.76497, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 15/50
# 2477/2477 [==============================] - 17s 7ms/step - loss: 0.8093 - acc: 0.7307 - val_loss: 0.7089 - val_acc: 0.7729
#
# Epoch 00015: val_loss improved from 0.76497 to 0.70890, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 16/50
# 2477/2477 [==============================] - 17s 7ms/step - loss: 0.7652 - acc: 0.7457 - val_loss: 0.7546 - val_acc: 0.7463
#
# Epoch 00016: val_loss did not improve from 0.70890
# Epoch 17/50
# 2477/2477 [==============================] - 17s 7ms/step - loss: 0.7653 - acc: 0.7493 - val_loss: 0.7725 - val_acc: 0.7463
#
# Epoch 00017: val_loss did not improve from 0.70890
# Epoch 18/50
# 2477/2477 [==============================] - 17s 7ms/step - loss: 0.7454 - acc: 0.7501 - val_loss: 0.6290 - val_acc: 0.7817
#
# Epoch 00018: val_loss improved from 0.70890 to 0.62902, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 19/50
# 2477/2477 [==============================] - 18s 7ms/step - loss: 0.7555 - acc: 0.7529 - val_loss: 0.7050 - val_acc: 0.7670
#
# Epoch 00019: val_loss did not improve from 0.62902
# Epoch 20/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 0.7024 - acc: 0.7755 - val_loss: 0.6275 - val_acc: 0.8053
#
# Epoch 00020: val_loss improved from 0.62902 to 0.62747, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 21/50
# 2477/2477 [==============================] - 17s 7ms/step - loss: 0.6763 - acc: 0.7622 - val_loss: 0.6339 - val_acc: 0.7847
#
# Epoch 00021: val_loss did not improve from 0.62747
# Epoch 22/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 0.6810 - acc: 0.7703 - val_loss: 0.6283 - val_acc: 0.7935
#
# Epoch 00022: val_loss did not improve from 0.62747
# Epoch 23/50
# 2477/2477 [==============================] - 17s 7ms/step - loss: 0.6330 - acc: 0.7981 - val_loss: 0.6029 - val_acc: 0.7876
#
# Epoch 00023: val_loss improved from 0.62747 to 0.60292, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 24/50
# 2477/2477 [==============================] - 17s 7ms/step - loss: 0.6487 - acc: 0.7897 - val_loss: 0.5750 - val_acc: 0.7847
#
# Epoch 00024: val_loss improved from 0.60292 to 0.57495, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 25/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 0.6374 - acc: 0.7897 - val_loss: 0.6323 - val_acc: 0.7965
#
# Epoch 00025: val_loss did not improve from 0.57495
# Epoch 26/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 0.6131 - acc: 0.7905 - val_loss: 0.6692 - val_acc: 0.7522
#
# Epoch 00026: val_loss did not improve from 0.57495
# Epoch 27/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 0.6252 - acc: 0.7848 - val_loss: 0.6263 - val_acc: 0.8053
#
# Epoch 00027: val_loss did not improve from 0.57495
# Epoch 28/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 0.5918 - acc: 0.8054 - val_loss: 0.6070 - val_acc: 0.7935
#
# Epoch 00028: val_loss did not improve from 0.57495
# Epoch 29/50
# 2477/2477 [==============================] - 16s 7ms/step - loss: 0.5942 - acc: 0.7957 - val_loss: 0.6025 - val_acc: 0.8083
#
# Epoch 00029: val_loss did not improve from 0.57495

# %% [markdown]
# ## Graph of training/validation Accuracy and Loss

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc', c='r')
plt.title('Training and validation accuracy')
plt.legend()
plt.subplot(1,2,2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss', c='r')
plt.title('Training and validation loss')
plt.legend();

# %%
# get index of predicted item for each image in test set
clothing_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(clothing_predictions)==np.argmax(test_targets, axis=1))/len(clothing_predictions)
print('Test accuracy: {}'.format(round(test_accuracy, 4)))
# Out:
# Test accuracy: 80.6647

# %%
# https://towardsdatascience.com/visualizing-intermediate-activation-in-convolutional
# -neural-networks-with-keras-260b36d60d0
model.save('saved_models/clothes2_cnn.h5')
# load the model with best validation loss
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %%
img_path = '../data/clothing2/test/spring_floral_dresses/spring_floral_dresses210.jpg'
img_tensor = path_to_tensor(img_path)
img_tensor /= 255.
plt.imshow(img_tensor[0])
plt.axis('off')
plt.show();

image = np.vstack([img_tensor])
classes = model.predict_classes(image)
print("Predicted class:", clothing_names[int(classes)])
# Out:
# Predicted class: spring_floral_dresses

# %% [markdown]
# ## Get a matrix of all images Dense layer stacked

# %%
all_clothing_paths = np.append(train_files, np.append(valid_files, test_files))

dense_layers, dense_df = get_dense_layers(model, all_clothing_paths)
pickle.dump(dense_df, open("saved_models/dense_clothing_df.pickle", "wb" ))
print(dense_layers.shape)
print(dense_df.shape)
dense_df.head()
# Out:
# (3147, 300)
# (3147, 300)
#                                                          0         1    \
# ../data/clothing2/train/black_skinny_jeans/blac... -0.000000 -0.000000
# ../data/clothing2/train/white_short_dresses/whi... -0.000000  0.872361
# ../data/clothing2/train/skinny_blue_jeans/skinn... -0.000000 -0.000000
# ../data/clothing2/train/royal_blue_short_dresse... -0.000000 -0.000000
# ../data/clothing2/train/running_shorts/running_...  0.569021  0.359611
#
#                                                          2         3    \
# ../data/clothing2/train/black_skinny_jeans/blac... -0.000000  0.852902
# ../data/clothing2/train/white_short_dresses/whi... -0.000000  0.827627
# ../data/clothing2/train/skinny_blue_jeans/skinn... -0.000000 -0.000000
# ../data/clothing2/train/royal_blue_short_dresse...  1.968974 -0.000000
# ../data/clothing2/train/running_shorts/running_...  0.183146 -0.000000
#
#                                                          4         5    6    \
# ../data/clothing2/train/black_skinny_jeans/blac... -0.000000 -0.000000 -0.0
# ../data/clothing2/train/white_short_dresses/whi...  0.686359  0.707280 -0.0
# ../data/clothing2/train/skinny_blue_jeans/skinn...  0.910299  1.145305 -0.0
# ../data/clothing2/train/royal_blue_short_dresse...  0.424211  0.918774 -0.0
# ../data/clothing2/train/running_shorts/running_...  1.037584  0.171459 -0.0
#
#                                                          7         8    9    \
# ../data/clothing2/train/black_skinny_jeans/blac...  0.774002  1.528834 -0.0
# ../data/clothing2/train/white_short_dresses/whi...  0.940041  0.983559 -0.0
# ../data/clothing2/train/skinny_blue_jeans/skinn...  0.398481 -0.000000 -0.0
# ../data/clothing2/train/royal_blue_short_dresse... -0.000000 -0.000000 -0.0
# ../data/clothing2/train/running_shorts/running_... -0.000000  0.043893 -0.0
#
#                                                       ...     290  291  292  \
# ../data/clothing2/train/black_skinny_jeans/blac...    ...    -0.0 -0.0 -0.0
# ../data/clothing2/train/white_short_dresses/whi...    ...    -0.0 -0.0 -0.0
# ../data/clothing2/train/skinny_blue_jeans/skinn...    ...    -0.0 -0.0 -0.0
# ../data/clothing2/train/royal_blue_short_dresse...    ...    -0.0 -0.0 -0.0
# ../data/clothing2/train/running_shorts/running_...    ...    -0.0 -0.0 -0.0
#
#                                                          293       294  295  \
# ../data/clothing2/train/black_skinny_jeans/blac... -0.000000 -0.000000 -0.0
# ../data/clothing2/train/white_short_dresses/whi...  0.539217  0.394101 -0.0
# ../data/clothing2/train/skinny_blue_jeans/skinn...  0.960778 -0.000000 -0.0
# ../data/clothing2/train/royal_blue_short_dresse...  1.146311 -0.000000 -0.0
# ../data/clothing2/train/running_shorts/running_...  0.465505 -0.000000 -0.0
#
#                                                     296       297       298  \
# ../data/clothing2/train/black_skinny_jeans/blac... -0.0  0.500662  0.376247
# ../data/clothing2/train/white_short_dresses/whi... -0.0 -0.000000  0.412421
# ../data/clothing2/train/skinny_blue_jeans/skinn... -0.0 -0.000000 -0.000000
# ../data/clothing2/train/royal_blue_short_dresse... -0.0 -0.000000 -0.000000
# ../data/clothing2/train/running_shorts/running_... -0.0 -0.000000 -0.000000
#
#                                                          299
# ../data/clothing2/train/black_skinny_jeans/blac... -0.000000
# ../data/clothing2/train/white_short_dresses/whi... -0.000000
# ../data/clothing2/train/skinny_blue_jeans/skinn... -0.000000
# ../data/clothing2/train/royal_blue_short_dresse...  1.276475
# ../data/clothing2/train/running_shorts/running_...  0.382149
#
# [5 rows x 300 columns]

# %% [markdown]
# ### K-Means cluster graph

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import pylab as pl

X = dense_layers
pca = PCA(n_components=2).fit(X)
pca_2d = pca.transform(X)
kmeans = KMeans(n_clusters=14, random_state=11)
kmeans.fit(X)
pl.figure()
pl.title('K-means with 14 clusters')
pl.scatter(pca_2d[:, 0], pca_2d[:, 1], c=kmeans.labels_, cmap='tab20');

# %% [markdown]
# ### T-SNE Graph

# %%
# https://datascience.stackexchange.com/questions/31700/how-to-print-kmeans-cluster-python
from sklearn.manifold import TSNE

# Embed the features into 2 features using TSNE
X_embedded_tsne = TSNE(n_components=2, perplexity=25).fit_transform(X)

plt.figure(figsize=(10,10))
plt.scatter(X_embedded_tsne[:,0], X_embedded_tsne[:,1], c = kmeans.labels_, cmap='tab20')
plt.title('TSNE of the Targets')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.colorbar()
plt.show();
# plt.tight_layout();

# %% [markdown]
# **Assign each file to a cluster**

# %%
# Assign each training file to a cluster for understanding the clusters and troubleshooting
for cluster_num in range(14):
    mask = np.where(kmeans.labels_ == cluster_num)[0]
    for idx in mask:
        print(f"Image {all_clothing_paths[idx]} is in cluster: {cluster_num}")
# Out:
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops91.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops240.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts291.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer123.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer160.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer108.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts186.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops178.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops181.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer165.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets42.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops26.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer54.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer88.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer114.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer145.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer124.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer45.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer8.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer109.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops107.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer143.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer94.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts270.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts3.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer58.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer1.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets93.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops209.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops127.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets220.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer153.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts148.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer144.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer11.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts180.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer119.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops57.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer152.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops88.jpg is in cluster: 0
# Image ../data/clothing2/train/black_short_dresses/black_short_dresses139.jpg is in cluster: 0
# Image ../data/clothing2/train/black_skinny_jeans/black_skinny_jeans97.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops190.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts200.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer134.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops180.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops81.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts199.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts273.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts233.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops53.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer105.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer135.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts24.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer185.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer57.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer26.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer115.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer71.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets28.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops39.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts33.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops115.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer138.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer169.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer18.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer14.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer76.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts276.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer146.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer163.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer148.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer173.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer102.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer98.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops223.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer103.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer166.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops85.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer12.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer161.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer171.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer67.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer21.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts13.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer77.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer159.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts162.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops102.jpg is in cluster: 0
# Image ../data/clothing2/train/black_skinny_jeans/black_skinny_jeans210.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer61.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer180.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets70.jpg is in cluster: 0
# Image ../data/clothing2/train/black_skinny_jeans/black_skinny_jeans129.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer15.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops256.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer42.jpg is in cluster: 0
# Image ../data/clothing2/train/black_skinny_jeans/black_skinny_jeans178.jpg is in cluster: 0
# Image ../data/clothing2/train/skinny_blue_jeans/skinny_blue_jeans231.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts255.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer117.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets194.jpg is in cluster: 0
# Image ../data/clothing2/train/black_skinny_jeans/black_skinny_jeans209.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts253.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer68.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer164.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops112.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer168.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer132.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops65.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts87.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts223.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops171.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer183.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer107.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops184.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer136.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts32.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer156.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer63.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer149.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer87.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer85.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets86.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer158.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer44.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer64.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer20.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops47.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer29.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer142.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets161.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer72.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts59.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops49.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer167.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer78.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops16.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer5.jpg is in cluster: 0
# Image ../data/clothing2/train/black_skinny_jeans/black_skinny_jeans166.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer187.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets131.jpg is in cluster: 0
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses230.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops122.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer82.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops167.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer74.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets199.jpg is in cluster: 0
# Image ../data/clothing2/train/skinny_blue_jeans/skinny_blue_jeans108.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer56.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer83.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer121.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer157.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer112.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops208.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer181.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops212.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets219.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer7.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops18.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts120.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer69.jpg is in cluster: 0
# Image ../data/clothing2/train/black_short_dresses/black_short_dresses64.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer150.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer95.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops116.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets6.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer49.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer35.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops235.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer0.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops254.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer129.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer101.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer170.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer66.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts95.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer106.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops0.jpg is in cluster: 0
# Image ../data/clothing2/train/brown_suede_jackets/brown_suede_jackets260.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts8.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer93.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts232.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops54.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer174.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer127.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops44.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops7.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops117.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer37.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer86.jpg is in cluster: 0
# Image ../data/clothing2/train/black_short_dresses/black_short_dresses232.jpg is in cluster: 0
# Image ../data/clothing2/train/long_sleeve_tops/long_sleeve_tops46.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer25.jpg is in cluster: 0
# Image ../data/clothing2/train/black_blazer/black_blazer33.jpg is in cluster: 0
# Image ../data/clothing2/train/running_shorts/running_shorts211.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer75.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_short_dresses/black_short_dresses184.jpg is in cluster: 0
# Image ../data/clothing2/validate/brown_suede_jackets/brown_suede_jackets39.jpg is in cluster: 0
# Image ../data/clothing2/validate/long_sleeve_tops/long_sleeve_tops111.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer175.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer4.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer116.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer182.jpg is in cluster: 0
# Image ../data/clothing2/validate/running_shorts/running_shorts226.jpg is in cluster: 0
# Image ../data/clothing2/validate/long_sleeve_tops/long_sleeve_tops161.jpg is in cluster: 0
# Image ../data/clothing2/validate/running_shorts/running_shorts147.jpg is in cluster: 0
# Image ../data/clothing2/validate/long_sleeve_tops/long_sleeve_tops93.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer89.jpg is in cluster: 0
# Image ../data/clothing2/validate/running_shorts/running_shorts237.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer147.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer133.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer126.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer36.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer22.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer110.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_skinny_jeans/black_skinny_jeans7.jpg is in cluster: 0
# Image ../data/clothing2/validate/long_sleeve_tops/long_sleeve_tops31.jpg is in cluster: 0
# Image ../data/clothing2/validate/black_blazer/black_blazer19.jpg is in cluster: 0
# Image ../data/clothing2/test/long_sleeve_tops/long_sleeve_tops101.jpg is in cluster: 0
# Image ../data/clothing2/test/long_sleeve_tops/long_sleeve_tops236.jpg is in cluster: 0
# Image ../data/clothing2/test/black_blazer/black_blazer39.jpg is in cluster: 0
# Image ../data/clothing2/test/black_blazer/black_blazer65.jpg is in cluster: 0
# Image ../data/clothing2/test/black_blazer/black_blazer104.jpg is in cluster: 0
# Image ../data/clothing2/test/black_blazer/black_blazer52.jpg is in cluster: 0
# Image ../data/clothing2/test/running_shorts/running_shorts157.jpg is in cluster: 0
# Image ../data/clothing2/test/black_blazer/black_blazer31.jpg is in cluster: 0
# Image ../data/clothing2/test/brown_suede_jackets/brown_suede_jackets29.jpg is in cluster: 0
# Image ../data/clothing2/test/black_short_dresses/black_short_dresses131.jpg is in cluster: 0
# Image ../data/clothing2/test/running_shorts/running_shorts14.jpg is in cluster: 0
# Image ../data/clothing2/test/black_blazer/black_blazer96.jpg is in cluster: 0
# Image ../data/clothing2/test/black_blazer/black_blazer131.jpg is in cluster: 0
# Image ../data/clothing2/test/brown_suede_jackets/brown_suede_jackets77.jpg is in cluster: 0
# Image ../data/clothing2/test/black_blazer/black_blazer111.jpg is in cluster: 0
# Image ../data/clothing2/test/black_blazer/black_blazer60.jpg is in cluster: 0
# Image ../data/clothing2/test/black_skinny_jeans/black_skinny_jeans10.jpg is in cluster: 0
# Image ../data/clothing2/test/black_blazer/black_blazer84.jpg is in cluster: 0
# Image ../data/clothing2/test/black_short_dresses/black_short_dresses158.jpg is in cluster: 0
# Image ../data/clothing2/test/black_blazer/black_blazer10.jpg is in cluster: 0
# Image ../data/clothing2/test/long_sleeve_tops/long_sleeve_tops207.jpg is in cluster: 0
# Image ../data/clothing2/test/running_shorts/running_shorts271.jpg is in cluster: 0
# Image ../data/clothing2/test/black_skinny_jeans/black_skinny_jeans87.jpg is in cluster: 0
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses205.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses206.jpg is in cluster: 1
# Image ../data/clothing2/train/white_pants/white_pants54.jpg is in cluster: 1
# Image ../data/clothing2/train/white_pants/white_pants173.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses229.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses217.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses187.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses47.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses50.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses89.jpg is in cluster: 1
# Image ../data/clothing2/train/khaki_pants/khaki_pants69.jpg is in cluster: 1
# Image ../data/clothing2/train/white_pants/white_pants21.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses100.jpg is in cluster: 1
# Image ../data/clothing2/train/white_pants/white_pants84.jpg is in cluster: 1
# Image ../data/clothing2/train/spring_floral_dresses/spring_floral_dresses3.jpg is in cluster: 1
# Image ../data/clothing2/train/white_pants/white_pants121.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses122.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses142.jpg is in cluster: 1
# Image ../data/clothing2/train/white_pants/white_pants161.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses209.jpg is in cluster: 1
# Image ../data/clothing2/train/running_shorts/running_shorts66.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dresses204.jpg is in cluster: 1
# Image ../data/clothing2/train/white_short_dresses/white_short_dres
jpg is in cluster: 13
# Image ../data/clothing2/test/khaki_pants/khaki_pants48.jpg is in cluster: 13
# Image ../data/clothing2/test/running_shorts/running_shorts292.jpg is in cluster: 13
# Image ../data/clothing2/test/khaki_pants/khaki_pants65.jpg is in cluster: 13
# Image ../data/clothing2/test/khaki_pants/khaki_pants20.jpg is in cluster: 13
# Image ../data/clothing2/test/khaki_pants/khaki_pants41.jpg is in cluster: 13
# Image ../data/clothing2/test/khaki_pants/khaki_pants122.jpg is in cluster: 13
# Image ../data/clothing2/test/khaki_pants/khaki_pants179.jpg is in cluster: 13
# Image ../data/clothing2/test/long_sleeve_tops/long_sleeve_tops52.jpg is in cluster: 13
# Image ../data/clothing2/test/khaki_pants/khaki_pants79.jpg is in cluster: 13

# %%
# number of images in each cluster
[np.where(kmeans.labels_ == cluster_num, 1, 0).sum() for cluster_num in range(14)]
# Out:
# [242, 456, 218, 149, 76, 187, 187, 158, 279, 241, 173, 499, 63, 219]

# %% [markdown]
# **Confusion matrix of labels and clusters**

# %%
targets1 = np.array([np.where(target == 1)[0][0] for target in train_targets])
targets2 = np.array([np.where(target == 1)[0][0] for target in valid_targets])
targets3 = np.array([np.where(target == 1)[0][0] for target in test_targets])
targets = np.append(targets1, np.append(targets2, targets3))

# %%
# create a confusion matrix out of the the labels and clusters
confusion = dict()

for target, label in zip(targets, kmeans.labels_):
    confusion[(target, label)] = confusion.get((target, label), 0) + 1

for target in range(14):
    line = '  '.join([f'{confusion.get((target,label),0):4d}' for label in range(14)])
    print(line)
# Out:
#  128     0     0     0     0     0     4     0    35     0     0     9     0     0
#    6     0     0     0     0     0     0     0   194     0     0    22     0     0
#    9     0     0     1     0     0   160     0     0     0     0    13     0     0
#   16     2     0     0     0     0     0     0    14     2   167    37     0     6
#    0    44     0     0     0     0     2     0     0     0     3    10     0   121
#    0    33     0     0     0     0     0     1     1   184     0    48     0     0
#   48    22     6     3     0     8     3    12    15    18     1    92    10     2
#    0     0   201     0     0     0     0     0     0     1     0    33    28     0
#    0     0     0     1    72   163     0     0     0     1     0    14     0     0
#   32     6    10     0     3    12     0     2     7    18     1    96    24    86
#    2     5     0   142     1     2    18     0     0     5     0    43     0     0
#    0    22     1     0     0     2     0   139     4    11     0    31     1     0
#    0   158     0     2     0     0     0     0     0     1     0     4     0     1
#    1   164     0     0     0     0     0     4     9     0     1    47     0     3

# %%
for i, name in enumerate(clothing_names):
    print(i,': ', name)
# Out:
# 0 :  black_blazer
# 1 :  black_short_dresses
# 2 :  black_skinny_jeans
# 3 :  brown_suede_jackets
# 4 :  khaki_pants
# 5 :  light_blue_short_dresses
# 6 :  long_sleeve_tops
# 7 :  red_short_dresses
# 8 :  royal_blue_short_dresses
# 9 :  running_shorts
# 10 :  skinny_blue_jeans
# 11 :  spring_floral_dresses
# 12 :  white_pants
# 13 :  white_short_dresses

# %%
# view the images of the clustered data to see if the clusters make sense
def view_image(image_path):
    plt.imshow(path_to_tensor(image_path)[0]/255.)

# %%
path1 = '../data/clothing2/train/royal_blue_short_dresses/royal_blue_short_dresses177.jpg'
path2 = '../data/clothing2/train/light_blue_short_dresses/light_blue_short_dresses173.jpg'

path3 = '../data/clothing2/train/long_sleeve_tops/long_sleeve_tops72.jpg'
path4 = '../data/clothing2/train/spring_floral_dresses/spring_floral_dresses128.jpg'

path5 = '../data/clothing2/train/running_shorts/running_shorts285.jpg'

# %%
view_image(path1)

# %%
view_image(path2)

# %%
view_image(path3)

# %%
view_image(path4)

# %%
view_image(path5)
